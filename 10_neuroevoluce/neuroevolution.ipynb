# %% [markdown]
# # Neuroevoluce

# %% [markdown]
# Pomocí evolučních algoritmů můžeme vyvíjet i celé neuronové sítě. Buď můžeme evolvovat váhy mezi neurony, strukturu sítě nebo obojí najednou. Nejprve se podíváme, jak naimplementovat jednoduchý algoritmus pro evoluci vah, následně si zkusíme i evoluci vah a struktury sítě najednou pomocí algoritmu NEAT.

# %% [markdown]
# ## Evoluce vah
#
# Evoluce vah je jednoduchá, stačí naimplementovat jednoduchou neuronovou síť, které umíme nastavit parametry. Náš jedinec v evoluci bude jeden dlouhý vektor, který bude reprezentovat váhy mezi vrstvami v neuronové síti. Při vyhodnocování tedy nastavíme síti váhy podle daného jedince a spočítáme její výstup. Zkusíme si tímto způsobem implementovat klasifikaci na našem oblíbeném datasetu iris.

# %%
import numpy as np

import sklearn

from deap import algorithms, creator, base, cma, tools

# %% [markdown]
# Začneme tím, že si připravíme jednoduchou implementaci neuronové sítě. Při inicializaci nastavíme vrstvy, jejich velikosti a také jejich aktivace, jelikož každá vrstva může mít svou vlastní aktivační funkci.
#
# Dále budeme potřebovat jednoho dlouhého linárního jedince všech vah rozdělit na váhové matice. To uděláme tak, že budeme brát vždy velikost akutální a následující vrstvy, na základě toho vezmeme odpovídající část jedince a vytvoříme z něj matici vah. Zároveň musíme přidat biasy, takže velikost aktuální vrstvy zvětšíme ještě o 1.
#
# Nakonec bude potřeba ještě funkce pro evaluaci sítě, která vytvořenou síť vyhodnotí tak, že pro každou vrstvu použije odpovídající aktivaci a vrátí nám výstup sítě.

# %%
class NeuralNetwork:
    def __init__(self, layer_sizes, activations):
        self.layer_sizes = layer_sizes
        self.layers = None

        # Checking, whether the number of activations corresponds to the number of layers
        if len(list(activations)) != len(layer_sizes) - 1:
            raise AttributeError("Number of activations does not match number of layers")
        
        self.activations = list(activations)
        self.vectorized_net = None


    # Returns total number of parameters of the network
    def vectorized_size(self):
        return sum(map(lambda x: (x[0] + 1) * x[1], zip(self.layer_sizes, self.layer_sizes[1:])))


    # Sets weights of the network using the values given by the linear individual
    def set_weights(self, vectorized_net):
        
        # Checking, whether the sizes match
        if len(vectorized_net) != self.vectorized_size():
            raise AttributeError(
                f"Length of vector does not match vectorized_size: {len(vectorized_net)} != {self.vectorized_size()}"
            )

        self.vectorized_net = vectorized_net
        self.layers = []
        sum_sizes = 0 # Sum of sizes of the previous layers (number of already processed elements)
        
        # Go through layers and set weight matrix between the current one and the following one
        # using the corresponding values from the linear indivudual.
        for (input_layer_size, output_layer_size) in zip(self.layer_sizes, self.layer_sizes[1:]):
            number_of_corresponding_elements = (input_layer_size + 1) * output_layer_size
            
            layer = vectorized_net[sum_sizes:(sum_sizes + number_of_corresponding_elements)]
            self.layers.append(np.reshape(layer, shape=(input_layer_size + 1, output_layer_size))) # Reshaping to the correct format
            
            sum_sizes += number_of_corresponding_elements


    # Evaluation of the network
    def eval_network(self, inputs):
        activations = inputs
        
        for activation_function, layer in zip(self.activations, self.layers):
            activations_1 = np.append(np.array([1.0]), activations)  # Extending the input vector by a constant one to be multiplied by the bias part of the weights
            activations = activation_function(np.dot(activations_1, layer))

        return activations

# %% [markdown]
# Nyní si akorát načteme data a rozdělíme si je na trénovací a testovací.

# %%
iris = sklearn.datasets.load_iris()
train_x, test_x, train_y, test_y = sklearn.model_selection.train_test_split(iris.data, iris.target)

# %% [markdown]
# Musíme si ještě definovat fitness funkci, což bude pouze vyhodnocení sítě na datech, kdy vždy vybereme jako predikovanou třídu tu s maximální pravděpodobností a spočítáme pak celkovou accuracy. Zároveň si definujeme vlastní lineární a relu aktivace.

# %%
def relu(x):
    return np.maximum(0, x)

def linear(x):
    return x

def fitness(net, ind, X, y):
    net.set_weights(ind)
    
    acc = 0
    for xi, yi in zip(X, y):
        if np.argmax(net.eval_network(xi)) == yi:
            acc += 1
    
    return acc / len(y),

# %% [markdown]
# Pro samotné nastavení vah neuronové sítě použíjeme algoritmus CMA-ES, což je evoluční strategie, která je velmi dobrá na úlohy spojité optimalizace, kterou máme i zde. V evoluční strategii se většinou nevyskytuje křížení, ale místo něj se klade důraz na mutaci. Zde se používá nám známá gaussovská mutace. CMA-ES funguje tak dobře proto, že nám umožňuje váhy měnit korelovaně, protože si pamatuje celou kovariační matici, ze které generuje jedince. Klasická evoluce umí měnit váhy jen nezávisle na sobě, a dává proto horší výsledky. CMA-ES je implementována v knihovně deap, a je tedy snadné ji použít.

# %%
net = NeuralNetwork([4, 5, 3], [relu, linear])
ind_size = net.vectorized_size()    
    
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("evaluate", lambda ind, X, y: fitness(net, ind, X, y), X=train_x, y=train_y)

strategy = cma.Strategy(centroid=[0.0] * ind_size, sigma=0.1, lambda_= 5 * ind_size)
toolbox.register("generate", strategy.generate, creator.Individual)
toolbox.register("update", strategy.update)

hof = tools.HallOfFame(1)
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("std", np.std)
stats.register("min", np.min)
stats.register("max", np.max)

_ = algorithms.eaGenerateUpdate(toolbox, ngen=250, stats=stats, halloffame=hof)
# Out:
# gen	nevals	avg     	std      	min	max
# 0  	215   	0.325042	0.0961401	0  	0.6875
# 1  	215   	0.333804	0.0881173	0  	0.6875
# 2  	215   	0.344601	0.112369 	0  	0.6875
# 3  	215   	0.334967	0.109849 	0  	0.883929
# 4  	215   	0.34456 	0.108217 	0  	0.6875
# 5  	215   	0.347218	0.0904068	0  	0.6875
# 6  	215   	0.360797	0.10356  	0  	0.830357
# 7  	215   	0.374294	0.107939 	0.0535714	0.6875
# 8  	215   	0.398879	0.122276 	0.107143 	0.803571
# 9  	215   	0.398131	0.14465  	0        	0.767857
# 10 	215   	0.386088	0.143196 	0        	0.714286
# 11 	215   	0.404527	0.145018 	0        	0.866071
# 12 	215   	0.403073	0.156573 	0        	0.928571
# 13 	215   	0.41495 	0.148799 	0.00892857	0.910714
# 14 	215   	0.425623	0.153815 	0         	0.991071
# 15 	215   	0.431686	0.165776 	0         	0.946429
# 16 	215   	0.45706 	0.157434 	0         	0.714286
# 17 	215   	0.446595	0.155315 	0         	0.866071
# 18 	215   	0.446927	0.16145  	0.00892857	0.767857
# 19 	215   	0.476786	0.167773 	0.0714286 	0.973214
# 20 	215   	0.460797	0.162612 	0         	0.973214
# 227	215   	0.990698	0.00178813	0.982143  	0.991071
# 228	215   	0.990698	0.00178813	0.982143  	0.991071
# 229	215   	0.990698	0.00178813	0.982143  	0.991071
# 230	215   	0.990324	0.00261859	0.973214  	0.991071
# 231	215   	0.990573	0.00204966	0.982143  	0.991071
# 232	215   	0.990739	0.00189671	0.973214  	0.991071
# 233	215   	0.990739	0.00189671	0.973214  	0.991071
# 234	215   	0.991071	1.11022e-16	0.991071  	0.991071
# 235	215   	0.990947	0.0010473  	0.982143  	0.991071
# 236	215   	0.990988	0.000857133	0.982143  	0.991071
# 237	215   	0.990988	0.000857133	0.982143  	0.991071
# 238	215   	0.990988	0.000857133	0.982143  	0.991071
# 239	215   	0.990905	0.00120647 	0.982143  	0.991071
# 240	215   	0.990947	0.00135588 	0.973214  	0.991071
# 241	215   	0.990822	0.00147059 	0.982143  	0.991071
# 242	215   	0.990947	0.0010473  	0.982143  	0.991071
# 243	215   	0.990947	0.0010473  	0.982143  	0.991071
# 244	215   	0.99103 	0.000607506	0.982143  	0.991071
# 245	215   	0.990988	0.000857133	0.982143  	0.991071
# 246	215   	0.990905	0.00148227 	0.973214  	0.991071
# 247	215   	0.990947	0.0010473  	0.982143  	0.991071
# 248	215   	0.990905	0.00120647 	0.982143  	0.991071
# 249	215   	0.991071	1.11022e-16	0.991071  	0.991071

# %% [markdown]
# Na závěr si zkusíme otestovat síť na testovacích datech a změřit na nich accuracy.

# %%
accuracy = fitness(net, hof[0], test_x, test_y)[0]
print("Achieved accuracy:", accuracy)
# Out:
# Achieved accuracy: 0.9736842105263158

# %% [markdown]
# ## NEAT
#
# Zkusíme se podívat na algoritmus NEAT na příkladu s datasetem iris a zkusíme pro něj najít co nejvhodnější síť, která bude umět data pokud možno co nejlépe klasifikovat. Samotná implementace algorimtu není vůbec jednoduchá, ale naštěstí v pythonu existuje knihovna neat-python, kde už tu práci někdo udělal za nás (instalujeme pomocí `pip install neat-python`). Knihovna má trochu jiný interface, než na co jsme zvyklí, ale není složité se jí naučit používat. Nastavení parametrů algoritmu se načítá ze zvláštního souboru *config-feedforward*. Dokumentace k jeho formátování se nachází [zde](https://neat-python.readthedocs.io/en/latest/config_file.html). Potom už stačí jen algoritmus spustit. Níže uvedený příklad vychází z dokumentace k [neat-python](https://github.com/CodeReclaimers/neat-python/tree/master/examples/xor) upravený pro naši klasifikaci irisů.

# %%
import neat
import visualize

# %%
# Construction and evaluation of a network in NEAT - basically a fitness function
def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        genome.fitness = 0.0
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        
        for xi, xo in zip(train_x, train_y): 
            output = net.activate(xi)
            if np.argmax(output) == xo:
                genome.fitness += 1

# %%
# Path to the configuration file
config_path = "config-feedforward"

# Load NEAT configuration
config = neat.Config(
    neat.DefaultGenome,
    neat.DefaultReproduction,
    neat.DefaultSpeciesSet,
    neat.DefaultStagnation,
    config_path
)

# Create new population
population = neat.Population(config)

# Add statistics computation for evolution logging
population.add_reporter(neat.StdOutReporter(show_species_detail=True))
stats = neat.StatisticsReporter()
population.add_reporter(stats)

# Run for a given number of generations
winner = population.run(eval_genomes, 100)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 35.48000 stdev: 14.20832
# Best fitness: 77.00000 - size: (3, 12) - species 1 - id 1
# Average adjusted fitness: 0.461
# Mean genetic distance 1.128, standard deviation 0.283
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    0   150     77.000    0.461     0
# Total extinctions: 0
# Generation time: 0.160 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 39.30000 stdev: 14.22428
# Best fitness: 103.00000 - size: (4, 13) - species 1 - id 230
# Average adjusted fitness: 0.382
# Mean genetic distance 1.184, standard deviation 0.258
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    1   150    103.000    0.382     0
# Total extinctions: 0
# Generation time: 0.163 sec (0.161 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 42.99333 stdev: 15.65609
# Best fitness: 103.00000 - size: (4, 13) - species 1 - id 230
# Average adjusted fitness: 0.406
# Mean genetic distance 1.275, standard deviation 0.227
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    2   150    103.000    0.406     1
# Total extinctions: 0
# Generation time: 0.156 sec (0.160 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 49.92000 stdev: 19.62023
# Best fitness: 103.00000 - size: (4, 13) - species 1 - id 230
# Average adjusted fitness: 0.480
# Mean genetic distance 1.400, standard deviation 0.269
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    3   150    103.000    0.480     2
# Total extinctions: 0
# Generation time: 0.175 sec (0.163 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 49.63333 stdev: 17.67424
# Best fitness: 103.00000 - size: (4, 13) - species 1 - id 230
# Average adjusted fitness: 0.482
# Mean genetic distance 1.526, standard deviation 0.300
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    4   150    103.000    0.482     3
# Total extinctions: 0
# Generation time: 0.168 sec (0.164 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 53.24667 stdev: 18.96943
# Best fitness: 103.00000 - size: (4, 13) - species 1 - id 230
# Average adjusted fitness: 0.517
# Mean genetic distance 1.556, standard deviation 0.272
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    5   150    103.000    0.517     4
# Total extinctions: 0
# Generation time: 0.176 sec (0.166 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 56.75333 stdev: 19.05429
# Best fitness: 105.00000 - size: (3, 9) - species 1 - id 1008
# Average adjusted fitness: 0.503
# Mean genetic distance 1.664, standard deviation 0.302
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    6   150    105.000    0.503     0
# Total extinctions: 0
# Generation time: 0.182 sec (0.169 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 56.66000 stdev: 19.32385
# Best fitness: 105.00000 - size: (3, 9) - species 1 - id 1008
# Average adjusted fitness: 0.309
# Mean genetic distance 1.889, standard deviation 0.370
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    7   150    105.000    0.309     1
# Total extinctions: 0
# Generation time: 0.171 sec (0.169 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 55.44667 stdev: 18.98369
# Best fitness: 105.00000 - size: (3, 9) - species 1 - id 1008
# Average adjusted fitness: 0.373
# Mean genetic distance 1.913, standard deviation 0.371
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    8   150    105.000    0.373     2
# Total extinctions: 0
# Generation time: 0.152 sec (0.167 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 58.02667 stdev: 19.23086
# Best fitness: 105.00000 - size: (3, 9) - species 1 - id 1008
# Average adjusted fitness: 0.329
# Mean genetic distance 2.073, standard deviation 0.544
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    9   140    105.000    0.329     3
#      2    0    10         --       --     0
# Total extinctions: 0
# Generation time: 0.175 sec (0.168 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 55.56667 stdev: 18.57504
# Best fitness: 105.00000 - size: (3, 9) - species 1 - id 1008
# Average adjusted fitness: 0.269
# Mean genetic distance 2.279, standard deviation 0.597
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   10   107    105.000    0.309     4
#      2    1    43     77.000    0.230     0
# Total extinctions: 0
# Generation time: 0.155 sec (0.167 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 58.31333 stdev: 19.40726
# Best fitness: 105.00000 - size: (3, 9) - species 1 - id 1008
# Average adjusted fitness: 0.376
# Mean genetic distance 2.215, standard deviation 0.602
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   11    89    105.000    0.360     5
#      2    2    61    101.000    0.391     0
# Total extinctions: 0
# Generation time: 0.170 sec (0.168 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 55.42667 stdev: 20.11479
# Best fitness: 106.00000 - size: (3, 5) - species 1 - id 1816
# Average adjusted fitness: 0.526
# Mean genetic distance 2.111, standard deviation 0.506
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   12    76    106.000    0.508     0
#      2    3    74    105.000    0.545     0
# Total extinctions: 0
# Generation time: 0.156 sec (0.168 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 58.88667 stdev: 20.47260
# Best fitness: 106.00000 - size: (3, 5) - species 2 - id 1816
# Average adjusted fitness: 0.337
# Mean genetic distance 2.015, standard deviation 0.462
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   13    69    104.000    0.295     1
#      2    4    81    106.000    0.379     0
# Total extinctions: 0
# Generation time: 0.162 sec (0.167 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 57.57333 stdev: 21.67467
# Best fitness: 106.00000 - size: (3, 5) - species 2 - id 1816
# Average adjusted fitness: 0.535
# Mean genetic distance 1.978, standard deviation 0.511
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   14    70    103.000    0.494     2
#      2    5    80    106.000    0.577     1
# Total extinctions: 0
# Generation time: 0.163 sec (0.166 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 56.32667 stdev: 20.96680
# Best fitness: 106.00000 - size: (3, 5) - species 2 - id 1816
# Average adjusted fitness: 0.296
# Mean genetic distance 1.972, standard deviation 0.595
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   15    72    103.000    0.227     3
#      2    6    78    106.000    0.364     2
# Total extinctions: 0
# Generation time: 0.140 sec (0.163 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 61.17333 stdev: 21.55821
# Best fitness: 106.00000 - size: (3, 4) - species 2 - id 2314
# Average adjusted fitness: 0.365
# Mean genetic distance 1.964, standard deviation 0.556
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   16    57    105.000    0.286     4
#      2    7    93    106.000    0.445     3
# Total extinctions: 0
# Generation time: 0.161 sec (0.160 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 59.47333 stdev: 20.79157
# Best fitness: 106.00000 - size: (3, 4) - species 2 - id 2314
# Average adjusted fitness: 0.332
# Mean genetic distance 1.934, standard deviation 0.541
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   17    74    103.000    0.280     5
#      2    8    76    106.000    0.384     4
# Total extinctions: 0
# Generation time: 0.141 sec (0.158 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 59.09333 stdev: 21.02866
# Best fitness: 106.00000 - size: (3, 4) - species 2 - id 2619
# Average adjusted fitness: 0.495
# Mean genetic distance 1.903, standard deviation 0.515
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   18    64    103.000    0.467     6
#      2    9    86    106.000    0.523     5
# Total extinctions: 0
# Generation time: 0.148 sec (0.157 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 55.68667 stdev: 21.64875
# Best fitness: 106.00000 - size: (3, 4) - species 2 - id 2619
# Average adjusted fitness: 0.519
# Mean genetic distance 1.857, standard deviation 0.538
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   19    65    104.000    0.472     7
#      2   10    85    106.000    0.565     6
# Total extinctions: 0
# Generation time: 0.156 sec (0.155 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 59.12000 stdev: 21.22732
# Best fitness: 106.00000 - size: (3, 3) - species 1 - id 2963
# Average adjusted fitness: 0.332
# Mean genetic distance 1.855, standard deviation 0.521
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   20    62    106.000    0.275     8
#      2   11    88    106.000    0.389     7
# Total extinctions: 0
# Generation time: 0.164 sec (0.156 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 57.94000 stdev: 20.33199
# Best fitness: 106.00000 - size: (3, 3) - species 1 - id 2963
# Average adjusted fitness: 0.541
# Mean genetic distance 2.000, standard deviation 0.459
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   21    70    106.000    0.506     9
#      2   12    80    106.000    0.575     8
# Total extinctions: 0
# Generation time: 0.148 sec (0.154 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 59.18000 stdev: 21.08177
# Best fitness: 106.00000 - size: (3, 3) - species 1 - id 2963
# Average adjusted fitness: 0.336
# Mean genetic distance 1.941, standard deviation 0.437
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   22    66    106.000    0.274    10
#      2   13    84    106.000    0.399     9
# Total extinctions: 0
# Generation time: 0.138 sec (0.152 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 60.01333 stdev: 22.06082
# Best fitness: 107.00000 - size: (3, 4) - species 2 - id 3498
# Average adjusted fitness: 0.555
# Mean genetic distance 1.844, standard deviation 0.428
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   23    71    106.000    0.510    11
#      2   14    79    107.000    0.601     0
# Total extinctions: 0
# Generation time: 0.146 sec (0.151 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 60.19333 stdev: 20.11987
# Best fitness: 107.00000 - size: (3, 4) - species 2 - id 3498
# Average adjusted fitness: 0.349
# Mean genetic distance 1.810, standard deviation 0.399
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   24    98    106.000    0.341    12
#      2   15    52    107.000    0.358     1
# Total extinctions: 0
# Generation time: 0.169 sec (0.151 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 63.20000 stdev: 22.18318
# Best fitness: 107.00000 - size: (3, 4) - species 2 - id 3498
# Average adjusted fitness: 0.457
# Mean genetic distance 1.780, standard deviation 0.369
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   25    62    106.000    0.419    13
#      2   16    88    107.000    0.496     2
# Total extinctions: 0
# Generation time: 0.145 sec (0.152 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 60.88667 stdev: 22.76885
# Best fitness: 107.00000 - size: (4, 7) - species 2 - id 3797
# Average adjusted fitness: 0.567
# Mean genetic distance 1.829, standard deviation 0.393
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   26   115    106.000    0.559    14
#      2   17    35    107.000    0.576     3
# Total extinctions: 0
# Generation time: 0.147 sec (0.150 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 63.51333 stdev: 20.92072
# Best fitness: 107.00000 - size: (4, 7) - species 2 - id 3797
# Average adjusted fitness: 0.404
# Mean genetic distance 1.757, standard deviation 0.435
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   27    97    106.000    0.389    15
#      2   18    53    107.000    0.419     4
# Total extinctions: 0
# Generation time: 0.165 sec (0.153 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 61.02667 stdev: 21.32477
# Best fitness: 107.00000 - size: (4, 7) - species 2 - id 3797
# Average adjusted fitness: 0.394
# Mean genetic distance 1.769, standard deviation 0.393
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   28   103    106.000    0.424    16
#      2   19    47    107.000    0.364     5
# Total extinctions: 0
# Generation time: 0.159 sec (0.154 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 60.66000 stdev: 20.77589
# Best fitness: 107.00000 - size: (4, 7) - species 1 - id 3797
# Average adjusted fitness: 0.351
# Mean genetic distance 1.820, standard deviation 0.399
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   29    82    107.000    0.365     0
#      2   20    68    107.000    0.338     6
# Total extinctions: 0
# Generation time: 0.251 sec (0.163 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 59.41333 stdev: 21.45140
# Best fitness: 107.00000 - size: (4, 7) - species 1 - id 3797
# Average adjusted fitness: 0.551
# Mean genetic distance 1.796, standard deviation 0.382
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   30    95    107.000    0.554     1
#      2   21    55    107.000    0.547     7
# Total extinctions: 0
# Generation time: 0.172 sec (0.164 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 61.89333 stdev: 21.05490
# Best fitness: 107.00000 - size: (4, 7) - species 1 - id 3797
# Average adjusted fitness: 0.408
# Mean genetic distance 1.768, standard deviation 0.342
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   31    72    107.000    0.402     2
#      2   22    78    107.000    0.414     8
# Total extinctions: 0
# Generation time: 0.169 sec (0.166 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 59.92667 stdev: 20.74836
# Best fitness: 107.00000 - size: (4, 7) - species 1 - id 3797
# Average adjusted fitness: 0.365
# Mean genetic distance 1.858, standard deviation 0.417
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   32    70    107.000    0.384     3
#      2   23    80    107.000    0.345     9
# Total extinctions: 0
# Generation time: 0.163 sec (0.169 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 59.12000 stdev: 20.60968
# Best fitness: 108.00000 - size: (3, 4) - species 2 - id 4960
# Average adjusted fitness: 0.532
# Mean genetic distance 1.840, standard deviation 0.407
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   33    73    107.000    0.561     4
#      2   24    77    108.000    0.503     0
# Total extinctions: 0
# Generation time: 0.179 sec (0.172 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 58.54000 stdev: 20.12084
# Best fitness: 108.00000 - size: (4, 8) - species 1 - id 5009
# Average adjusted fitness: 0.365
# Mean genetic distance 1.873, standard deviation 0.402
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   34    87    108.000    0.348     0
#      2   25    63    108.000    0.383     1
# Total extinctions: 0
# Generation time: 0.150 sec (0.170 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 59.05333 stdev: 22.10936
# Best fitness: 108.00000 - size: (4, 8) - species 1 - id 5009
# Average adjusted fitness: 0.539
# Mean genetic distance 1.774, standard deviation 0.420
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   35    93    108.000    0.562     1
#      2   26    57    108.000    0.515     2
# Total extinctions: 0
# Generation time: 0.185 sec (0.174 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 56.68667 stdev: 20.74484
# Best fitness: 108.00000 - size: (4, 8) - species 1 - id 5009
# Average adjusted fitness: 0.408
# Mean genetic distance 1.709, standard deviation 0.374
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   36    88    108.000    0.389     2
#      2   27    62    108.000    0.427     3
# Total extinctions: 0
# Generation time: 0.175 sec (0.177 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 59.95333 stdev: 21.69219
# Best fitness: 108.00000 - size: (4, 8) - species 1 - id 5009
# Average adjusted fitness: 0.533
# Mean genetic distance 1.700, standard deviation 0.374
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   37    86    108.000    0.560     3
#      2   28    64    108.000    0.507     4
# Total extinctions: 0
# Generation time: 0.191 sec (0.179 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 57.72000 stdev: 21.06027
# Best fitness: 108.00000 - size: (4, 8) - species 1 - id 5009
# Average adjusted fitness: 0.507
# Mean genetic distance 1.788, standard deviation 0.403
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   38    92    108.000    0.538     4
#      2   29    58    108.000    0.477     5
# Total extinctions: 0
# Generation time: 0.154 sec (0.179 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 58.02000 stdev: 20.62118
# Best fitness: 108.00000 - size: (4, 8) - species 1 - id 5009
# Average adjusted fitness: 0.303
# Mean genetic distance 1.703, standard deviation 0.435
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   39    94    108.000    0.358     5
#      2   30    56    107.000    0.248     6
# Total extinctions: 0
# Generation time: 0.156 sec (0.169 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 60.52000 stdev: 21.36437
# Best fitness: 108.00000 - size: (4, 8) - species 2 - id 5009
# Average adjusted fitness: 0.352
# Mean genetic distance 1.691, standard deviation 0.412
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   40    72    108.000    0.341     6
#      2   31    78    108.000    0.364     7
# Total extinctions: 0
# Generation time: 0.144 sec (0.167 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 63.76667 stdev: 22.60691
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 4960
# Average adjusted fitness: 0.400
# Mean genetic distance 1.770, standard deviation 0.461
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   41    60    108.000    0.356     7
#      2   32    90    108.000    0.445     8
# Total extinctions: 0
# Generation time: 0.156 sec (0.165 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 61.24667 stdev: 22.68037
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.358
# Mean genetic distance 1.829, standard deviation 0.452
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   42    71    108.000    0.348     8
#      2   33    79    108.000    0.367     9
# Total extinctions: 0
# Generation time: 0.149 sec (0.164 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 60.42667 stdev: 22.12761
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.560
# Mean genetic distance 1.903, standard deviation 0.508
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   43    53    108.000    0.564     9
#      2   34    97    108.000    0.555    10
# Total extinctions: 0
# Generation time: 0.167 sec (0.163 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 58.68667 stdev: 20.30998
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.328
# Mean genetic distance 1.984, standard deviation 0.456
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   44    64    108.000    0.341    10
#      2   35    86    108.000    0.315    11
# Total extinctions: 0
# Generation time: 0.168 sec (0.164 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 61.30667 stdev: 22.13984
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.572
# Mean genetic distance 1.879, standard deviation 0.505
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   45    54    108.000    0.603    11
#      2   36    96    108.000    0.541    12
# Total extinctions: 0
# Generation time: 0.154 sec (0.161 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 58.80667 stdev: 21.66586
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.535
# Mean genetic distance 1.892, standard deviation 0.479
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   46    61    108.000    0.580    12
#      2   37    89    108.000    0.490    13
# Total extinctions: 0
# Generation time: 0.156 sec (0.159 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 59.52000 stdev: 22.53315
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.546
# Mean genetic distance 1.956, standard deviation 0.469
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   47    80    108.000    0.584    13
#      2   38    70    108.000    0.507    14
# Total extinctions: 0
# Generation time: 0.147 sec (0.155 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 61.13333 stdev: 21.95166
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.439
# Mean genetic distance 1.928, standard deviation 0.462
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   48    78    108.000    0.489    14
#      2   39    72    108.000    0.388    15
# Total extinctions: 0
# Generation time: 0.165 sec (0.156 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 60.14667 stdev: 21.02709
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.408
# Mean genetic distance 1.939, standard deviation 0.418
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   49    72    108.000    0.442    15
#      2   40    78    108.000    0.374    16
# Total extinctions: 0
# Generation time: 0.170 sec (0.158 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 58.80667 stdev: 21.52570
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.326
# Mean genetic distance 2.031, standard deviation 0.402
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   50    54    108.000    0.327    16
#      2   41    96    108.000    0.325    17
# Total extinctions: 0
# Generation time: 0.148 sec (0.158 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 61.57333 stdev: 22.85646
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.570
# Mean genetic distance 2.029, standard deviation 0.412
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   51    99    108.000    0.568    17
#      2   42    51    108.000    0.571    18
# Total extinctions: 0
# Generation time: 0.173 sec (0.160 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 59.08667 stdev: 21.70927
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 6023
# Average adjusted fitness: 0.326
# Mean genetic distance 2.149, standard deviation 0.385
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   52    32    108.000    0.339    18
#      2   43   118    104.000    0.313    19
# Total extinctions: 0
# Generation time: 0.163 sec (0.161 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 63.24000 stdev: 21.03923
# Best fitness: 108.00000 - size: (3, 5) - species 2 - id 7704
# Average adjusted fitness: 0.354
# Mean genetic distance 1.939, standard deviation 0.372
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   53   101     77.000    0.296    19
#      2   44    49    108.000    0.412    20
# Total extinctions: 0
# Generation time: 0.157 sec (0.160 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 60.38667 stdev: 20.51951
# Best fitness: 108.00000 - size: (3, 5) - species 1 - id 7704
# Average adjusted fitness: 0.371
# Mean genetic distance 1.725, standard deviation 0.304
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   54    93    108.000    0.354    20
#      2   45    57    102.000    0.388    21
# Total extinctions: 0
# Generation time: 0.179 sec (0.161 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 65.24000 stdev: 19.95217
# Best fitness: 108.00000 - size: (3, 5) - species 2 - id 7704
# Average adjusted fitness: 0.415
# Mean genetic distance 1.620, standard deviation 0.334
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   55    30    108.000    0.413    21
#      2   46   120    108.000    0.416    22
# Total extinctions: 0
# Generation time: 0.184 sec (0.164 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 66.27333 stdev: 21.96691
# Best fitness: 108.00000 - size: (4, 7) - species 2 - id 7024
# Average adjusted fitness: 0.415
# Mean genetic distance 1.622, standard deviation 0.363
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   56    51    100.000    0.392    22
#      2   47    99    108.000    0.438    23
# Total extinctions: 0
# Generation time: 0.168 sec (0.165 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 61.39333 stdev: 22.01209
# Best fitness: 108.00000 - size: (3, 5) - species 2 - id 7704
# Average adjusted fitness: 0.564
# Mean genetic distance 1.583, standard deviation 0.320
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   57   133    103.000    0.551    23
#      2   48    17    108.000    0.577    24
# Total extinctions: 0
# Generation time: 0.185 sec (0.169 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 63.31333 stdev: 22.90302
# Best fitness: 108.00000 - size: (5, 5) - species 1 - id 8539
# Average adjusted fitness: 0.431
# Mean genetic distance 1.580, standard deviation 0.309
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   58    89    108.000    0.375    24
#      2   49    61    105.000    0.486    25
# Total extinctions: 0
# Generation time: 0.166 sec (0.169 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 64.20667 stdev: 23.30330
# Best fitness: 108.00000 - size: (3, 4) - species 1 - id 8605
# Average adjusted fitness: 0.537
# Mean genetic distance 1.655, standard deviation 0.315
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   59    95    108.000    0.547    25
#      2   50    55    105.000    0.527    26
# Total extinctions: 0
# Generation time: 0.180 sec (0.170 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 58.62667 stdev: 21.17846
# Best fitness: 108.00000 - size: (6, 8) - species 1 - id 8783
# Average adjusted fitness: 0.325
# Mean genetic distance 1.726, standard deviation 0.325
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   60   104    108.000    0.320    26
#      2   51    46    105.000    0.331    27
# Total extinctions: 0
# Generation time: 0.186 sec (0.174 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 64.60000 stdev: 22.43747
# Best fitness: 110.00000 - size: (3, 5) - species 2 - id 8932
#
# Best individual in generation 61 meets fitness threshold - complexity: (3, 5)

# %%
# Show the best individual and its accuracy on test data
print(f"*Best genome*\n{winner}")

winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
num_of_correct_predictions = 0
for input_example, correct_output in zip(test_x, test_y):
    output = winner_net.activate(input_example)
    prediction = np.argmax(output)
        
    if prediction == correct_output:
        num_of_correct_predictions += 1
    
print("\nTotal accuracy on the test data:", num_of_correct_predictions / len(test_y))

# Render the best network
node_names = {-1:"x1", -2: "x2", -3: "x3", -4: "x4", 0:"setosa", 1:"virginica", 2:"versicolor"}
visualize.draw_net(
    config,
    genome=winner,
    node_names=node_names,
    show_disabled=True,
    prune_unused=False
)

# Plot the statistics
visualize.plot_stats(stats, ylog=False, view=True)
visualize.plot_species(stats, view=True)
# Out:
# *Best genome*
# Key: 8932
# Fitness: 110.0
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=2.8697550909795773, response=1.0, activation=sigmoid, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.8569812163274534, response=1.0, activation=sigmoid, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=-1.357009134139029, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-4, 1), innovation=3568, weight=-3.025783565740777, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), innovation=7, weight=-3.8893161561508873, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), innovation=9, weight=4.568320047504199, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), innovation=4, weight=1.107964108101693, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), innovation=1, weight=-1.621072912153101, enabled=False)
# 	DefaultConnectionGene(key=(-1, 1), innovation=2, weight=0.611378392943167, enabled=False)
# 	DefaultConnectionGene(key=(-1, 2), innovation=140, weight=-4.21749984140112, enabled=True)
#
# Total accuracy on the test data: 0.9210526315789473

# %% [markdown]
# ## Domácí úkol - Zpětnovazební učení s využitím neuroevoluce
#
# Za domácí úkol budete mít vyzkoušet si vyřešit některá prostředí z knihovny [Gymnasium](https://gymnasium.farama.org/). Vyzkoušet můžete buď NEAT (v takovém případě můžete použít třeba knihovnu, kterou jsme si právě vyzkoušeli, jen nezapomeňte přizpůsobit konfigurační soubor, fitness a tak podobně), vyvíjet jen vektor vah fixní sítě, nebo cokoli vás napadne.
#
# [Detailní zadání](https://kam.mff.cuni.cz/~lorenc/teach/PIA_hw/homeworks-neuroevolution.html) je možno najít na stránkách cvičení.
